# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns
import matplotlib.dates as mdates

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,6

# %%
from src import data

# %%
import itertools

# %%
providers = ['apple', 'google']
countries = ['france', 'germany']

providers_countries = list(itertools.product(countries,providers))
nrows=len(providers_countries)
fig, axs = plt.subplots(nrows=nrows, figsize=(15,6*nrows), sharex=True)


for ax,(country,provider) in zip(axs,providers_countries):
    df = data.load_mobility(country, provider)
    sns.lineplot(data=df, ax=ax)
    ax.set_title(f"{provider} mobility reports: {country}")
    ax.set_ylabel("% change from baseline")
    ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=mdates.MO))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
    ax.set_xlim(left=datetime.date(2020, 2, 15))

# %%
data.load_mobility(agregate='week_avg')
# Out:
#              mean_pct
# date
# 2020-02-16   4.250000
# 2020-02-23   3.190476
# 2020-03-01  -0.047619
# 2020-03-08  -1.214286
# 2020-03-15  -1.595238
# 2020-03-22 -44.595238
# 2020-03-29 -54.476190
# 2020-04-05 -52.833333
# 2020-04-12 -50.928571
# 2020-04-19 -51.690476
# 2020-04-26 -48.833333
# 2020-05-03 -46.000000

# %%
providers = ['apple', 'google']
countries = ['france', 'germany']

providers_countries = list(itertools.product(countries,providers))
nrows=len(providers_countries)
fig, axs = plt.subplots(nrows=nrows, figsize=(15,6*nrows), sharex=True)


for ax,(country,provider) in zip(axs,providers_countries):
    df = data.load_mobility(country, provider)
    sns.lineplot(data=df.resample('W').mean(), ax=ax)
    ax.set_title(f"{provider} mobility reports: {country}")
    ax.set_ylabel("% change from baseline")
    ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=mdates.MO))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
    ax.set_xlim(left=datetime.date(2020, 2, 15))

# %%
providers = ['apple', 'google']
countries = ['france', 'germany']

providers_countries = list(itertools.product(countries,providers))
nrows=len(providers_countries)
fig, axs = plt.subplots(nrows=nrows, figsize=(15,6*nrows), sharex=True)


for ax,(country,provider) in zip(axs,providers_countries):
    df = data.load_mobility(country, provider)
    sns.lineplot(data=df.resample('W').mean().mean(axis=1), ax=ax)
    ax.set_title(f"{provider} mobility reports (average): {country}")
    ax.set_ylabel("% change from baseline")
    ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=mdates.MO))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
    ax.set_xlim(left=datetime.date(2020, 2, 15))
