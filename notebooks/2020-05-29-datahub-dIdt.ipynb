# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,6

# %%
from src import data, viz

# %%
import datetime

# %%
start_date=datetime.date(2020, 2, 15)
countries = ['france', 'germany', 'denmark']
nrows=len(countries)

fig, axs = plt.subplots(nrows=nrows, figsize=(6.4,2.4*nrows), sharex=True)


for ax,country in zip(axs, countries):
    df = data.load_covid19(country)
    sns.lineplot(data=df.diff(),ax=ax)
    viz.format_xaxis_dates(ax)
    ax.xaxis.set_tick_params(rotation=45)
    ax.set_title(f"Covid-19 {country}")
    ax.set_xlim(left=start_date)

# %%
start_date=datetime.date(2020, 2, 15)
countries = ['france', 'germany', 'denmark']
nrows=len(countries)

fig, axs = plt.subplots(nrows=nrows, figsize=(6.4,2.4*nrows), sharex=True)


for ax,country in zip(axs, countries):
    df = data.load_covid19(country)
    sns.lineplot(data=df,ax=ax)
    viz.format_xaxis_dates(ax)
    ax.xaxis.set_tick_params(rotation=45)
    ax.set_title(f"Covid-19 {country}")
    ax.set_xlim(left=start_date)

# %%
df_icl = data.load_imperial_college_results()

# %%
start_date=datetime.date(2020, 2, 15)
countries = ['france', 'germany', 'denmark']
nrows=len(countries)

fig, axs = plt.subplots(nrows=nrows, figsize=(6.4,2.4*nrows), sharex=True)


for ax,country in zip(axs, countries):
    df_icl = data.load_imperial_college_results(country=country)
    sns.lineplot(data=df_icl.loc[:,['reported_cases']],ax=ax)
    viz.format_xaxis_dates(ax)
    ax.xaxis.set_tick_params(rotation=45)
    ax.set_title(f"Covid-19 {country}")
    ax.set_xlim(left=start_date)
