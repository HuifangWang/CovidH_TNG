# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns
import matplotlib.dates as mdates

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,6

# %%
from src import data

# %%
df_france = data.load_google_mobility_france()
df_france.head()
# Out:
# /home/izaak/local_repos/glyptodon/happileptor-data/env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#             retail_and_recreation_percent_change_from_baseline  \
# date
# 2020-02-15                                               -2.0
# 2020-02-16                                                6.0
# 2020-02-17                                                1.0
# 2020-02-18                                                5.0
# 2020-02-19                                               -4.0
#
#             grocery_and_pharmacy_percent_change_from_baseline  \
# date
# 2020-02-15                                               -1.0
# 2020-02-16                                                2.0
# 2020-02-17                                                2.0
# 2020-02-18                                                2.0
# 2020-02-19                                               -3.0
#
#             parks_percent_change_from_baseline  \
# date
# 2020-02-15                                23.0
# 2020-02-16                                 9.0
# 2020-02-17                                16.0
# 2020-02-18                                36.0
# 2020-02-19                                18.0
#
#             transit_stations_percent_change_from_baseline  \
# date
# 2020-02-15                                           12.0
# 2020-02-16                                            7.0
# 2020-02-17                                           -6.0
# 2020-02-18                                           -4.0
# 2020-02-19                                           -6.0
#
#             workplaces_percent_change_from_baseline  \
# date
# 2020-02-15                                     -2.0
# 2020-02-16                                     -1.0
# 2020-02-17                                    -15.0
# 2020-02-18                                    -14.0
# 2020-02-19                                    -12.0
#
#             residential_percent_change_from_baseline
# date
# 2020-02-15                                      -1.0
# 2020-02-16                                      -1.0
# 2020-02-17                                       4.0
# 2020-02-18                                       3.0
# 2020-02-19                                       2.0

# %%
ax = sns.lineplot(data=df_france)
ax.set_title("Google Mobility reports: France")
ax.set_ylabel("% change from baseline")
ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=mdates.MO))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
