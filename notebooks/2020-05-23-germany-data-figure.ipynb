# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext lab_black

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,6

# %%
from src import data

# %%
data.load_cosmo_phi().plot()

# %%
data.load_covid19(country="germany").plot()

# %%
data.loa
